# %%
import pandas as pd
from pathlib import Path
from sklearn.metrics import roc_auc_score, average_precision_score
import numpy as np

split = "validation"
output_dir = "full_pairs_within_split"
split_path = Path(output_dir) / f"split_{split}"

all_files = sorted(split_path.glob("batch_*.parquet"))

y_true_list = []
y_score_list = []

for f in all_files:
    df = pd.read_parquet(f, columns=["label", "score"])  # читаем только нужные столбцы
    y_true_list.append(df["label"].astype(int).to_numpy())
    y_score_list.append(df["score"].astype(float).to_numpy())
    del df

y_true = np.concatenate(y_true_list)
y_score = np.concatenate(y_score_list)

roc_auc = roc_auc_score(y_true, y_score)
pr_auc = average_precision_score(y_true, y_score)

print("ROC-AUC:", roc_auc)
print("PR-AUC (Average Precision):", pr_auc)
# Out:
# ROC-AUC: 0.9958007575223794
# PR-AUC (Average Precision): 0.7400264082039862

# %%
split = "test"
output_dir = "full_pairs_within_split"
split_path = Path(output_dir) / f"split_{split}"

all_files = sorted(split_path.glob("batch_*.parquet"))

y_true_list = []
y_score_list = []

for f in all_files:
    df = pd.read_parquet(f, columns=["label", "score"])  # читаем только нужные столбцы
    y_true_list.append(df["label"].astype(int).to_numpy())
    y_score_list.append(df["score"].astype(float).to_numpy())
    del df

y_true = np.concatenate(y_true_list)
y_score = np.concatenate(y_score_list)

roc_auc = roc_auc_score(y_true, y_score)
pr_auc = average_precision_score(y_true, y_score)

print("ROC-AUC:", roc_auc)
print("PR-AUC (Average Precision):", pr_auc)
# Out:
# ROC-AUC: 0.9844468308508513
# PR-AUC (Average Precision): 0.5141045335826284

# %%
split = "validation"
output_dir = "all_pairs_for_split"
split_path = Path(output_dir) / f"split_{split}"

all_files = sorted(split_path.glob("batch_*.parquet"))

y_true_list = []
y_score_list = []

for f in all_files:
    df = pd.read_parquet(f, columns=["label", "score"])  # читаем только нужные столбцы
    y_true_list.append(df["label"].astype(int).to_numpy())
    y_score_list.append(df["score"].astype(float).to_numpy())
    del df

y_true = np.concatenate(y_true_list)
y_score = np.concatenate(y_score_list)

roc_auc = roc_auc_score(y_true, y_score)
pr_auc = average_precision_score(y_true, y_score)

print("ROC-AUC:", roc_auc)
print("PR-AUC (Average Precision):", pr_auc)
# Out:
# ROC-AUC: 0.994560015545541
# PR-AUC (Average Precision): 0.4911688227109976

# %%
split = "test"
output_dir = "all_pairs_for_split"
split_path = Path(output_dir) / f"split_{split}"

all_files = sorted(split_path.glob("batch_*.parquet"))

y_true_list = []
y_score_list = []

for f in all_files:
    df = pd.read_parquet(f, columns=["label", "score"])  # читаем только нужные столбцы
    y_true_list.append(df["label"].astype(int).to_numpy())
    y_score_list.append(df["score"].astype(float).to_numpy())
    del df

y_true = np.concatenate(y_true_list)
y_score = np.concatenate(y_score_list)

roc_auc = roc_auc_score(y_true, y_score)
pr_auc = average_precision_score(y_true, y_score)

print("ROC-AUC:", roc_auc)
print("PR-AUC (Average Precision):", pr_auc)
# Out:
# ROC-AUC: 0.9809933066999187
# PR-AUC (Average Precision): 0.14359178399420355

# %%
import json

with open('full_pairs_within_split/split_validation/summary.json', 'r') as file:
    data_dict = json.load(file)
print('graph+catboost valid')    
print(data_dict)
# Out:
# graph+catboost valid
# {'split': 'validation', 'n_profiles': 12474, 'n_total_pairs': 77794101, 'pair_batch_size': 200000, 'n_saved_rows': 77794101, 'n_saved_files': 389, 'metrics': {'TP': 3637, 'FP': 515, 'FN': 4828, 'TN': 77785121, 'precision': 0.8759633911368016, 'recall': 0.42965150620200826, 'f1_score': 0.5765237378140604}}

# %%
with open('full_pairs_within_split/split_test/summary.json', 'r') as file:
    data_dict = json.load(file)
print('graph+catboost test')    
print(data_dict)
# Out:
# graph+catboost test
# {'split': 'test', 'n_profiles': 12384, 'n_total_pairs': 76675536, 'pair_batch_size': 200000, 'n_saved_rows': 76675536, 'n_saved_files': 384, 'metrics': {'TP': 1059, 'FP': 337, 'FN': 1357, 'TN': 76672783, 'precision': 0.7585959885386819, 'recall': 0.4383278145695364, 'f1_score': 0.555613850996852}}

# %%
with open('all_pairs_for_split/split_validation/summary.json', 'r') as file:
    data_dict = json.load(file)
print('catboost only validation')    
print(data_dict)
# Out:
# catboost only validation
# {'split': 'validation', 'n_profiles': 12474, 'n_total_pairs': 77794101, 'pair_batch_size': 200000, 'save_only_current_split_pairs': True, 'save_only_above_threshold': False, 'n_current_pairs': 77794101, 'n_saved_rows': 77794101, 'n_saved_files': 389, 'metrics': {'TP': 7652, 'FP': 236181, 'FN': 813, 'TN': 77549455, 'precision': 0.03138213449369035, 'recall': 0.9039574719432959, 'f1_score': 0.06065842773228484}}

# %%
with open('all_pairs_for_split/split_test/summary.json', 'r') as file:
    data_dict = json.load(file)
print('catboost only test')    
print(data_dict)
# Out:
# catboost only test
# {'split': 'test', 'n_profiles': 12384, 'n_total_pairs': 76675536, 'pair_batch_size': 200000, 'save_only_current_split_pairs': True, 'save_only_above_threshold': False, 'n_current_pairs': 76675536, 'n_saved_rows': 76675536, 'n_saved_files': 384, 'metrics': {'TP': 1754, 'FP': 362343, 'FN': 662, 'TN': 76310777, 'precision': 0.004817397561638794, 'recall': 0.7259933774834437, 'f1_score': 0.009571283965370941}}
